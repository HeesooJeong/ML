# %%
# -*- coding: utf-8 -*-
"""머러기.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1bpcx4Z4jm9o4PpJP5uxxSRUmX30OXnuQ
"""

import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/etc/23_fes.csv')
df['budget'] = df['budget'].astype(float).astype(int)
df['visitors'] = df['visitors'].astype(float).astype(int)

df.info()

#가시성 위해 아웃라이어 제거
df2 = df[df['visitors'] <= 1000000]

df3 = df2[df2['budget'] <= 3000]

sns.scatterplot(data=df3, x="budget", y="visitors", hue="sort")
plt.show()

sns.scatterplot(data=df3, x="budget", y="visitors", hue="location")
plt.show()

sns.boxplot(data=df3, x="budget", y="visitors")
plt.show()

sns.lineplot(data=df3, x="budget", y="visitors", hue="location")
plt.show()

sns.lineplot(data=df3, x="budget", y="visitors", hue="sort")
plt.show()
